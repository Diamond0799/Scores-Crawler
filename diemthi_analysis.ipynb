# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('./diemthi_nghean.csv')
df
# Out:
#             SBD  Toan  Ngu Van  Ngoai Ngu  Vat Ly  Hoa Hoc  Sinh Hoc  Lich Su  \
# 0      29000001   9.0     7.00        8.8    8.75      4.0      4.25    -1.00
# 1      29000002   2.8     4.25       -1.0   -1.00     -1.0     -1.00     6.75
# 2      29000003   4.4     7.25        4.0   -1.00     -1.0     -1.00     7.00
# 3      29000004   7.6    -1.00       -1.0    6.75      8.0      2.75    -1.00
# 4      29000005   7.8     9.00        8.6   -1.00     -1.0     -1.00     4.00
# ...         ...   ...      ...        ...     ...      ...       ...      ...
# 34477  29034476   5.2     7.50        4.2   -1.00     -1.0     -1.00     7.50
# 34478  29034477   5.6     7.50        3.0   -1.00     -1.0     -1.00     5.00
# 34479  29034478   5.2     8.00        6.2   -1.00     -1.0     -1.00     4.75
# 34480  29034479   3.8     4.75        5.0   -1.00     -1.0     -1.00     3.75
# 34481  29034480   7.2     6.25        4.2   -1.00     -1.0     -1.00     2.75
#
#        Dia Ly  GDCD  So Mon Thi
# ...

# %%
KC = df[df['Ngu Van'].notnull() & df['Lich Su'].notnull() & df['Dia Ly'].notnull()]

# %%
KC = KC.loc[:, ['SBD', 'Ngu Van', 'Lich Su', 'Dia Ly']]
KC['C'] = KC['Ngu Van'] + KC['Lich Su'] + KC['Dia Ly']

# %%
KC[KC['C'] > 26.5]
KC.describe()
KC[KC['C'] > 25].C.round(1).value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
KA = df[df['Toan'].notnull() & df['Vat Ly'].notnull() & df['Hoa Hoc'].notnull()]

# %%
KA['A'] = KA['Toan'] + KA['Vat Ly'] + KA['Hoa Hoc']
KA = KA.loc[:, ['SBD', 'Toan', 'Vat Ly', 'Hoa Hoc', 'A']]
KA.describe()
# Out:
# /tmp/ipykernel_29387/3505156213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KA['A'] = KA['Toan'] + KA['Vat Ly'] + KA['Hoa Hoc']
#                 SBD          Toan        Vat Ly       Hoa Hoc             A
# count  1.006300e+04  10063.000000  10063.000000  10063.000000  10063.000000
# mean   2.901579e+07      8.003657      6.604268      6.644738     21.252663
# std    1.002539e+04      1.012497      1.590451      1.785352      3.457841
# min    2.900000e+07      1.400000      1.000000      0.750000      6.250000
# 25%    2.900687e+07      7.600000      5.500000      5.250000     19.250000
# 50%    2.901476e+07      8.200000      7.000000      7.250000     21.750000
# ...

# %%
df[df['Toan'] == 10]
df[df['Vat Ly'] == 10]
df[df['Hoa Hoc'] == 10]
# Out:
#             SBD  Toan  Ngu Van  Ngoai Ngu  Vat Ly  Hoa Hoc  Sinh Hoc  Lich Su  \
# 439    29000440   9.2     8.50        7.6    8.50     10.0      4.75      NaN
# 3368   29003369   9.2     8.50        8.4    4.75     10.0      9.50      NaN
# 3386   29003387   9.4     7.75        7.6    6.75     10.0     10.00      NaN
# 3684   29003685   8.8     7.25        8.8    4.25     10.0      9.25      NaN
# 11072  29011073   9.8      NaN        NaN     NaN     10.0      9.75      NaN
# 11078  29011079   9.0      NaN        NaN     NaN     10.0      9.50      NaN
# 11279  29011280   9.6      NaN        NaN    8.75     10.0      1.75      NaN
# 11365  29011366   8.6     6.25        6.4    8.50     10.0      4.50      NaN
# 11643  29011644   8.2      NaN        NaN     NaN     10.0      8.75      NaN
# 13301  29013301   9.0     9.25        7.0    5.50     10.0      8.75      NaN
# 14091  29014091   9.0     6.50        7.8    8.75     10.0      9.50      NaN
# ...

# %%
# df = df.fillna(-1)
# df['So Mon Thi'] = 0
# for row in range(df.shape[0]):
#     for col in range(1, df.shape[1] - 1):
#         if df.iloc[row, col] != -1:
#             df.iloc[row, 10] += 1
#     print(row)

# %%
df2 = df[df['SBD'] < 29000100]

# %%
# df2 = df2.fillna(-1)
# df2['So Mon Thi'] = 0
# for row in range(df2.shape[0]):
#     for col in list(range(1, df2.shape[1] - 1)):
#         if df2.iloc[row, col] != -1:
#             df2.iloc[row, 10] += 1

# %%
for row in range(df.shape[0]):
    for col in range(1, df.shape[1] - 1):
        if df.iloc[row, col] == -1:
            df.iloc[row, col] = np.nan

# %%
df[df['So Mon Thi'] == 3]
# Out:
#             SBD  Toan  Ngu Van  Ngoai Ngu  Vat Ly  Hoa Hoc  Sinh Hoc  Lich Su  \
# 23     29000024   8.8      NaN        8.6    8.75      NaN       NaN      NaN
# 69     29000070   8.0     8.75        9.4     NaN      NaN       NaN      NaN
# 73     29000074   5.4      NaN        4.6    3.75      NaN       NaN      NaN
# 76     29000077   8.8      NaN        NaN    7.25     7.50       NaN      NaN
# 84     29000085   8.8     8.75        9.4     NaN      NaN       NaN      NaN
# ...         ...   ...      ...        ...     ...      ...       ...      ...
# 33754  29033753   NaN     7.50        NaN     NaN      NaN       NaN     3.50
# 33820  29033819   8.6      NaN        NaN    7.50     7.75       NaN      NaN
# 33920  29033919   NaN     7.00        NaN     NaN      NaN       NaN     6.25
# 34093  29034092   5.6     8.00        8.0     NaN      NaN       NaN      NaN
# 34459  29034458   7.6      NaN        6.8    7.25      NaN       NaN      NaN
#
#        Dia Ly  GDCD  So Mon Thi
# ...
